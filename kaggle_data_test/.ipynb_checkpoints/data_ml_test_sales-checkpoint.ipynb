# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os


import xgboost as xgb
from sklearn.metrics import mean_squared_error

# %%
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
my_file = os.getcwd() +  '/data/train.csv'

df = pd.read_csv(my_file)
df = df.set_index('date')
df.index = pd.to_datetime(df.index)

df =df.drop(columns='id')
df
# Out:
#             store_nbr                      family     sales  onpromotion
# date
# 2013-01-01          1                  AUTOMOTIVE     0.000            0
# 2013-01-01          1                   BABY CARE     0.000            0
# 2013-01-01          1                      BEAUTY     0.000            0
# 2013-01-01          1                   BEVERAGES     0.000            0
# 2013-01-01          1                       BOOKS     0.000            0
# ...               ...                         ...       ...          ...
# 2017-08-15          9                     POULTRY   438.133            0
# 2017-08-15          9              PREPARED FOODS   154.553            1
# 2017-08-15          9                     PRODUCE  2419.729          148
# 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000            8
# 2017-08-15          9                     SEAFOOD    16.000            0
#
# [3000888 rows x 4 columns]

# %%
store_1 = df.loc[df['store_nbr'] == 1]
store_1 = store_1.drop(columns='store_nbr')
store_1.head()
# Out:
#                 family  sales  onpromotion
# date
# 2013-01-01  AUTOMOTIVE    0.0            0
# 2013-01-01   BABY CARE    0.0            0
# 2013-01-01      BEAUTY    0.0            0
# 2013-01-01   BEVERAGES    0.0            0
# 2013-01-01       BOOKS    0.0            0

# %%
store_1['family'].unique()
# Out:
# array(['AUTOMOTIVE', 'BABY CARE', 'BEAUTY', 'BEVERAGES', 'BOOKS',
#        'BREAD/BAKERY', 'CELEBRATION', 'CLEANING', 'DAIRY', 'DELI', 'EGGS',
#        'FROZEN FOODS', 'GROCERY I', 'GROCERY II', 'HARDWARE',
#        'HOME AND KITCHEN I', 'HOME AND KITCHEN II', 'HOME APPLIANCES',
#        'HOME CARE', 'LADIESWEAR', 'LAWN AND GARDEN', 'LINGERIE',
#        'LIQUOR,WINE,BEER', 'MAGAZINES', 'MEATS', 'PERSONAL CARE',
#        'PET SUPPLIES', 'PLAYERS AND ELECTRONICS', 'POULTRY',
#        'PREPARED FOODS', 'PRODUCE', 'SCHOOL AND OFFICE SUPPLIES',
#        'SEAFOOD'], dtype=object)

# %%
store_1_cleaning = store_1.loc[ (store_1['family'] == 'CLEANING')]
store_1_cleaning = store_1_cleaning.drop(columns='family')
fig, ax = plt.subplots(figsize=(15, 5))

store_1_cleaning['sales'].plot(ax=ax, label='sales', title='train data')
store_1_cleaning['onpromotion'].plot(ax=ax, label='promo')
plt.show()

# %%
store_1_cleaning
# Out:
#              sales  onpromotion
# date
# 2013-01-01     0.0            0
# 2013-01-02  1060.0            0
# 2013-01-03   836.0            0
# 2013-01-04   827.0            0
# 2013-01-05   811.0            0
# ...            ...          ...
# 2017-08-11   341.0            7
# 2017-08-12   351.0            8
# 2017-08-13   169.0            5
# 2017-08-14   571.0           11
# 2017-08-15   703.0           10
#
# [1684 rows x 2 columns]

# %%
store_1_cleaning.loc[(store_1_cleaning.index > '2015-01-01') & (store_1_cleaning.index < '2015-03-01')] \
    .plot(figsize=(15, 5), title='Week Of Data')
plt.show()

# %%
def define_topic(df, store_number, topic):
    df = df.copy()
    df = df.loc[df['store_nbr'] == store_number]
    df = df.drop(columns='store_nbr')
    df = df.loc[ (df['family'] == topic)]
    df = df.drop(columns='family')
    return df

store_1_CELEBRATION = define_topic(df, 1, 'CELEBRATION' )
store_1_CELEBRATION
# Out:
#             sales  onpromotion
# date
# 2013-01-01    0.0            0
# 2013-01-02    0.0            0
# 2013-01-03    0.0            0
# 2013-01-04    0.0            0
# 2013-01-05    0.0            0
# ...           ...          ...
# 2017-08-11    4.0            0
# 2017-08-12    3.0            0
# 2017-08-13    1.0            0
# 2017-08-14    4.0            0
# 2017-08-15   21.0            0
#
# [1684 rows x 2 columns]

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    return df

store_1_cleaning = create_features(store_1_cleaning)

store_1_cleaning
# Out:
#              sales  onpromotion  dayofweek  quarter  month  year  dayofyear  \
# date
# 2013-01-01     0.0            0          1        1      1  2013          1
# 2013-01-02  1060.0            0          2        1      1  2013          2
# 2013-01-03   836.0            0          3        1      1  2013          3
# 2013-01-04   827.0            0          4        1      1  2013          4
# 2013-01-05   811.0            0          5        1      1  2013          5
# ...            ...          ...        ...      ...    ...   ...        ...
# 2017-08-11   341.0            7          4        3      8  2017        223
# 2017-08-12   351.0            8          5        3      8  2017        224
# 2017-08-13   169.0            5          6        3      8  2017        225
# 2017-08-14   571.0           11          0        3      8  2017        226
# 2017-08-15   703.0           10          1        3      8  2017        227
#
#             dayofmonth
# date
# ...

# %%
store_1_cleaning.dtypes
# Out:
# sales          float64
# onpromotion      int64
# dayofweek        int64
# quarter          int64
# month            int64
# year             int64
# dayofyear        int64
# dayofmonth       int64
# dtype: object

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=store_1_cleaning, x='dayofweek', y='sales')
ax.set_title('sales by day')
plt.show()

# %%
train = store_1_cleaning.loc[store_1_cleaning.index < '2017-01-01']
test = store_1_cleaning.loc[store_1_cleaning.index >= '2017-01-01']

fig, ax = plt.subplots(figsize=(15, 5))
train['sales'].plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test['sales'].plot(ax=ax, label='Test Set')
ax.axvline('2017-01-01', color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %%
FEATURES = ['dayofyear', 'dayofweek', 'month', 'year', 'dayofmonth', 'onpromotion']
TARGET = 'sales'

X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=1000,
                       early_stopping_rounds=50,
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [22:35:15] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:666.01337	validation_1-rmse:692.42602
# [100]	validation_0-rmse:273.40131	validation_1-rmse:296.48574
# [200]	validation_0-rmse:153.37963	validation_1-rmse:170.18700
# [300]	validation_0-rmse:124.65043	validation_1-rmse:136.85847
# [400]	validation_0-rmse:116.96844	validation_1-rmse:128.11397
# [500]	validation_0-rmse:113.39067	validation_1-rmse:126.06041
# [600]	validation_0-rmse:111.13203	validation_1-rmse:124.89855
# [700]	validation_0-rmse:109.31672	validation_1-rmse:124.05061
# [800]	validation_0-rmse:107.47974	validation_1-rmse:123.60307
# [827]	validation_0-rmse:106.99650	validation_1-rmse:123.63613
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
# ...

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
             index=reg.feature_names_in_,
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
test['prediction'] = reg.predict(X_test)
store_1_cleaning= store_1_cleaning.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = store_1_cleaning[['sales']].plot(figsize=(15, 5))
store_1_cleaning['prediction'].plot(ax=ax, style='--')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Dat and Prediction')
plt.show()
# Out:
# <ipython-input-298-e7c3dc4df0c5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['prediction'] = reg.predict(X_test)

# %%
ax = store_1_cleaning.loc[(store_1_cleaning.index > '04-01-2017') & (store_1_cleaning.index < '07-08-2017')]['sales'] \
    .plot(figsize=(15, 5), title='Week Of Data')
store_1_cleaning.loc[(store_1_cleaning.index > '04-01-2017') & (store_1_cleaning.index < '07-08-2017')]['prediction'] \
    .plot(style='--')
plt.legend(['Truth Data','Prediction'])
plt.show()

# %%
score = np.sqrt(mean_squared_error(test['sales'], test['prediction']))
print(f'RMSE Score on Test set: {score:0.2f}')
# Out:
# RMSE Score on Test set: 123.57

# %%
test['error'] = np.abs(test[TARGET] - test['prediction'])

test
# Out:
# <ipython-input-301-6ee3f148adc0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['error'] = np.abs(test[TARGET] - test['prediction'])
#              sales  onpromotion  dayofweek  quarter  month  year  dayofyear  \
# date
# 2017-01-01     0.0            0          6        1      1  2017          1
# 2017-01-02   332.0            7          0        1      1  2017          2
# 2017-01-03   952.0           18          1        1      1  2017          3
# 2017-01-04  1055.0           15          2        1      1  2017          4
# 2017-01-05   918.0           10          3        1      1  2017          5
# ...            ...          ...        ...      ...    ...   ...        ...
# ...

# %%
def add_lags(df):
    target_map = df['sales'].to_dict()
    df['lag1'] = (df.index - pd.Timedelta('364 days')).map(target_map)
    df['lag2'] = (df.index - pd.Timedelta('728 days')).map(target_map)
    df['lag3'] = (df.index - pd.Timedelta('1092 days')).map(target_map)
    return df

# %%
store_1_cleaning = add_lags(store_1_cleaning)

store_1_cleaning
# Out:
#              sales  onpromotion  dayofweek  quarter  month  year  dayofyear  \
# date
# 2013-01-01     0.0            0          1        1      1  2013          1
# 2013-01-02  1060.0            0          2        1      1  2013          2
# 2013-01-03   836.0            0          3        1      1  2013          3
# 2013-01-04   827.0            0          4        1      1  2013          4
# 2013-01-05   811.0            0          5        1      1  2013          5
# ...            ...          ...        ...      ...    ...   ...        ...
# 2017-08-11   341.0            7          4        3      8  2017        223
# 2017-08-12   351.0            8          5        3      8  2017        224
# 2017-08-13   169.0            5          6        3      8  2017        225
# 2017-08-14   571.0           11          0        3      8  2017        226
# 2017-08-15   703.0           10          1        3      8  2017        227
#
# ...

# %%
store_1_cleaning = create_features(store_1_cleaning)

FEATURES = ['dayofyear', 'dayofweek', 'month', 'year', 'dayofmonth', 'onpromotion',
            'lag1','lag2','lag3']
TARGET = 'sales'

X_all = store_1_cleaning[FEATURES]
y_all = store_1_cleaning[TARGET]

reg = xgb.XGBRegressor(base_score=0.5,
                       booster='gbtree',    
                       n_estimators=500,
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_all, y_all,
        eval_set=[(X_all, y_all)],
        verbose=100)
# Out:
# [22:35:17] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:669.59646
# [100]	validation_0-rmse:274.35468
# [200]	validation_0-rmse:152.59611
# [300]	validation_0-rmse:122.74607
# [400]	validation_0-rmse:114.89563
# [499]	validation_0-rmse:111.78348
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.01, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=3, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=500, n_jobs=0,
# ...

# %%
store_1_cleaning.index.max()
# Out:
# Timestamp('2017-08-15 00:00:00')

# %%
my_file = os.getcwd() +  '/data/test.csv'

future_df = pd.read_csv(my_file)
future_df = future_df.set_index('date')
future_df.index = pd.to_datetime(future_df.index)

future_df =future_df.drop(columns='id')
future_df
# Out:
#             store_nbr                      family  onpromotion
# date
# 2017-08-16          1                  AUTOMOTIVE            0
# 2017-08-16          1                   BABY CARE            0
# 2017-08-16          1                      BEAUTY            2
# 2017-08-16          1                   BEVERAGES           20
# 2017-08-16          1                       BOOKS            0
# ...               ...                         ...          ...
# 2017-08-31          9                     POULTRY            1
# 2017-08-31          9              PREPARED FOODS            0
# 2017-08-31          9                     PRODUCE            1
# 2017-08-31          9  SCHOOL AND OFFICE SUPPLIES            9
# 2017-08-31          9                     SEAFOOD            0
#
# [28512 rows x 3 columns]

# %%
future_df = define_topic(future_df, 1, 'CLEANING' )
future_df
# Out:
#             onpromotion
# date
# 2017-08-16           25
# 2017-08-17            7
# 2017-08-18            6
# 2017-08-19           11
# 2017-08-20            4
# 2017-08-21            9
# 2017-08-22           10
# 2017-08-23           11
# 2017-08-24           12
# 2017-08-25            8
# 2017-08-26           10
# 2017-08-27            7
# 2017-08-28           11
# 2017-08-29           13
# 2017-08-30           11
# 2017-08-31           12

# %%
future_df['isFuture'] = True
store_1_cleaning['isFuture'] = False
df_and_future = pd.concat([store_1_cleaning, future_df])
df_and_future = create_features(df_and_future)
df_and_future = add_lags(df_and_future)

df_and_future
# Out:
#              sales  onpromotion  dayofweek  quarter  month  year  dayofyear  \
# date
# 2013-01-01     0.0            0          1        1      1  2013          1
# 2013-01-02  1060.0            0          2        1      1  2013          2
# 2013-01-03   836.0            0          3        1      1  2013          3
# 2013-01-04   827.0            0          4        1      1  2013          4
# 2013-01-05   811.0            0          5        1      1  2013          5
# ...            ...          ...        ...      ...    ...   ...        ...
# 2017-08-27     NaN            7          6        3      8  2017        239
# 2017-08-28     NaN           11          0        3      8  2017        240
# 2017-08-29     NaN           13          1        3      8  2017        241
# 2017-08-30     NaN           11          2        3      8  2017        242
# 2017-08-31     NaN           12          3        3      8  2017        243
#
# ...

# %%
future_w_features = df_and_future.query('isFuture').copy()
future_w_features
# Out:
#             sales  onpromotion  dayofweek  quarter  month  year  dayofyear  \
# date
# 2017-08-16    NaN           25          2        3      8  2017        228
# 2017-08-17    NaN            7          3        3      8  2017        229
# 2017-08-18    NaN            6          4        3      8  2017        230
# 2017-08-19    NaN           11          5        3      8  2017        231
# 2017-08-20    NaN            4          6        3      8  2017        232
# 2017-08-21    NaN            9          0        3      8  2017        233
# 2017-08-22    NaN           10          1        3      8  2017        234
# 2017-08-23    NaN           11          2        3      8  2017        235
# 2017-08-24    NaN           12          3        3      8  2017        236
# 2017-08-25    NaN            8          4        3      8  2017        237
# 2017-08-26    NaN           10          5        3      8  2017        238
# ...

# %%
future_w_features['pred'] = reg.predict(future_w_features[FEATURES])
future_w_features
# Out:
#             sales  onpromotion  dayofweek  quarter  month  year  dayofyear  \
# date
# 2017-08-16    NaN           25          2        3      8  2017        228
# 2017-08-17    NaN            7          3        3      8  2017        229
# 2017-08-18    NaN            6          4        3      8  2017        230
# 2017-08-19    NaN           11          5        3      8  2017        231
# 2017-08-20    NaN            4          6        3      8  2017        232
# 2017-08-21    NaN            9          0        3      8  2017        233
# 2017-08-22    NaN           10          1        3      8  2017        234
# 2017-08-23    NaN           11          2        3      8  2017        235
# 2017-08-24    NaN           12          3        3      8  2017        236
# 2017-08-25    NaN            8          4        3      8  2017        237
# 2017-08-26    NaN           10          5        3      8  2017        238
# ...

# %%
future_w_features['pred'].plot(figsize=(10, 5),
                               color=color_pal[2],
                               ms=1,
                               lw=1,
                               title='Future Predictions')
plt.show()

# %%
store_1_cleaning_and_futures = pd.concat([store_1_cleaning, future_w_features])

store_1_cleaning_and_futures
# Out:
#              sales  onpromotion  dayofweek  quarter  month  year  dayofyear  \
# date
# 2013-01-01     0.0            0          1        1      1  2013          1
# 2013-01-02  1060.0            0          2        1      1  2013          2
# 2013-01-03   836.0            0          3        1      1  2013          3
# 2013-01-04   827.0            0          4        1      1  2013          4
# 2013-01-05   811.0            0          5        1      1  2013          5
# ...            ...          ...        ...      ...    ...   ...        ...
# 2017-08-27     NaN            7          6        3      8  2017        239
# 2017-08-28     NaN           11          0        3      8  2017        240
# 2017-08-29     NaN           13          1        3      8  2017        241
# 2017-08-30     NaN           11          2        3      8  2017        242
# 2017-08-31     NaN           12          3        3      8  2017        243
#
# ...

# %%
ax = store_1_cleaning_and_futures.loc[(store_1_cleaning_and_futures.index > '2017-08-01') & (store_1_cleaning_and_futures.index <= '2017-08-31')]['sales'] \
    .plot(figsize=(15, 5), title='Week Of Data')
store_1_cleaning_and_futures.loc[(store_1_cleaning_and_futures.index > '2017-08-01') & (store_1_cleaning_and_futures.index <= '2017-08-31')]['pred'] \
    .plot(style='--')
store_1_cleaning_and_futures.loc[(store_1_cleaning_and_futures.index > '2017-08-01') & (store_1_cleaning_and_futures.index <= '2017-08-31')]['onpromotion'] \
    .plot(style='.')
plt.legend(['Truth Data','Prediction'])
plt.show()

# %%
ax = store_1_cleaning_and_futures.loc[(store_1_cleaning_and_futures.index > '2016-08-01') & (store_1_cleaning_and_futures.index < '2016-08-30')]['sales'] \
    .plot(figsize=(15, 5), title='Week Of Data')
store_1_cleaning_and_futures.loc[(store_1_cleaning_and_futures.index > '2016-08-01') & (store_1_cleaning_and_futures.index <= '2016-08-31')]['onpromotion'] \
    .plot(style='.')
plt.legend(['Truth Data','Prediction'])
plt.show()
